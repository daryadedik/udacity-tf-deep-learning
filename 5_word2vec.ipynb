# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %%
words[:15]
# Out:
# ['anarchism',
#  'originated',
#  'as',
#  'a',
#  'term',
#  'of',
#  'abuse',
#  'first',
#  'used',
#  'against',
#  'early',
#  'working',
#  'class',
#  'radicals',
#  'including']

# %% [markdown]
# Build the dictionary and replace rare words with UNK token. We simply calculate here the number of words we meet in words.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:10])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764), ('in', 372201), ('a', 325873), ('to', 316376), ('zero', 264975), ('nine', 250430)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'a', 'originated', 'as', 'term', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['anarchism', 'originated', 'a', 'term', 'originated', 'of', 'term', 'as']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %% [markdown]
# Each step:
#
# 1. Generate minibatch with size 128: batch size = 128, batch labels = 128
# 2. feed_dict constructs a dictionary for train dataset and train labels
# 3. session.run passes to training defined above

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.248854
# Nearest to has: suzuki, malthus, reckless, scholars, donner, guybrush, disallow, phantoms,
# Nearest to was: piano, goodnight, vests, cumann, kitsch, wrote, cookery, landforms,
# Nearest to there: pam, shortens, visit, thermodynamic, anguilla, sunda, popularised, willamette,
# Nearest to during: pyotr, tamil, exons, hallows, escu, dopant, onstage, pioneered,
# Nearest to american: minoan, atari, coordinating, progressively, fixtures, evaluates, distract, forehead,
# Nearest to states: espa, waco, thalberg, reuse, colloid, seriously, pair, alberto,
# Nearest to other: scuola, ridge, capitalised, petrels, kor, severan, waste, logone,
# Nearest to will: ocs, landon, craving, hesperides, mathematik, clo, damnation, uncles,
# Nearest to after: shasta, reclaimed, subtractive, surely, spatial, eia, jafar, miscellaneous,
# Nearest to while: muhammed, winnie, tell, ord, ensures, voltaic, lsch, mindaugas,
# Nearest to for: frontage, salamander, pointwise, ballarat, dejima, predisposition, reconnection, desktop,
# Nearest to many: frigate, dione, parochial, muay, planing, fainter, siblings, modernization,
# Nearest to and: westwards, influenza, hammurabi, exception, absurdities, deteriorated, queene, triplet,
# Nearest to history: squalor, aircraft, persecutions, inexperience, reductase, cheer, juden, zf,
# Nearest to world: issuing, digestive, interference, gymnast, almost, epi, mikado, dishes,
# Nearest to a: doctrines, draw, slipknot, periods, uncommonly, bnls, seif, realtime,
# Average loss at step 2000: 4.363378
# Average loss at step 4000: 3.867156
# Average loss at step 6000: 3.790941
# Average loss at step 8000: 3.691062
# Average loss at step 10000: 3.616627
# Nearest to has: had, was, is, have, autobahn, bestowing, devolution, gus,
# Nearest to was: is, has, had, were, by, are, cookery, evasive,
# Nearest to there: it, they, he, transcendent, nowak, not, dowd, still,
# Nearest to during: asmara, malvern, fuelled, pyotr, restless, bail, massif, epiphanes,
# Nearest to american: staffs, koan, viva, county, atari, michael, english, carta,
# Nearest to states: waco, pair, thalberg, espa, vanes, seriously, reuse, ask,
# Nearest to other: scuola, these, feeders, essays, census, install, ourselves, acquire,
# Nearest to will: would, can, to, cannot, mathematik, uncles, undesired, skywalker,
# Nearest to after: miscellaneous, replacements, subtractive, as, antibacterial, repulse, shasta, from,
# Nearest to while: voltaic, ensures, cameos, entrepreneurs, lsch, winnie, conformal, humankind,
# Nearest to for: of, in, with, buick, okavango, removing, knowable, sugarcane,
# Nearest to many: some, opened, hummel, all, erv, features, forte, few,
# Nearest to and: or, massif, alemanni, british, rigged, installs, amounting, but,
# Nearest to history: aircraft, mountain, squalor, inexperience, admirers, persecutions, median, cheer,
# Nearest to world: interference, issuing, ducati, underlines, gymnast, constructible, thayer, bundesland,
# Nearest to a: the, fidel, oratory, platters, no, this, station, previously,
# Average loss at step 12000: 3.603136
# Average loss at step 14000: 3.569585
# Average loss at step 16000: 3.414338
# Average loss at step 18000: 3.454476
# Average loss at step 20000: 3.539496
# Nearest to has: had, have, was, is, having, utilize, infantile, incomplete,
# Nearest to was: is, has, were, had, became, be, matchbox, are,
# Nearest to there: they, it, he, nowak, which, said, still, not,
# Nearest to during: asmara, into, massif, bail, malvern, despite, pyotr, exons,
# Nearest to american: british, staffs, english, viva, county, arnold, scoping, michael,
# Nearest to states: waco, vanes, colloid, countries, seriously, reuse, lackluster, espa,
# Nearest to other: many, these, different, paphos, causes, several, scuola, provoke,
# Nearest to will: would, can, could, cannot, may, to, must, should,
# Nearest to after: from, before, miscellaneous, hormone, for, prodigious, antibacterial, purportedly,
# Nearest to while: entrepreneurs, voltaic, anchored, generator, though, humankind, cameos, lsch,
# Nearest to for: einen, of, after, with, okavango, by, removing, in,
# Nearest to many: some, several, all, these, other, various, features, most,
# Nearest to and: or, but, naughty, were, samples, which, who, in,
# Nearest to history: compaor, median, mercury, aircraft, junctions, mountain, squalor, tbilisi,
# Nearest to world: interference, issuing, underlines, ducati, gymnast, misidentification, digestive, workshop,
# Nearest to a: the, any, no, fidel, this, royale, previously, ebert,
# Average loss at step 22000: 3.499447
# Average loss at step 24000: 3.488401
# Average loss at step 26000: 3.481656
# Average loss at step 28000: 3.484828
# Average loss at step 30000: 3.500939
# Nearest to has: had, have, is, was, having, autobahn, since, semite,
# Nearest to was: is, had, were, has, became, been, ala, dataset,
# Nearest to there: they, it, he, said, she, still, which, nowak,
# Nearest to during: in, after, from, despite, into, until, at, economist,
# Nearest to american: british, english, viva, koan, staffs, county, french, and,
# Nearest to states: waco, countries, vanes, lackluster, nations, seriously, reuse, espa,
# Nearest to other: these, different, paphos, many, several, proponents, are, some,
# Nearest to will: would, can, could, may, should, cannot, must, to,
# Nearest to after: before, from, during, until, when, for, hormone, miscellaneous,
# Nearest to while: though, when, however, entrepreneurs, generator, valved, voltaic, where,
# Nearest to for: after, with, of, during, einen, against, from, when,
# Nearest to many: some, several, these, all, various, most, bok, other,
# Nearest to and: or, but, from, marian, in, american, perlite, however,
# Nearest to history: compaor, median, squalor, pastiches, aircraft, ten, wafers, witnesses,
# Nearest to world: interference, underlines, rule, antiarrhythmic, issuing, plane, fib, nanyang,
# Nearest to a: any, no, the, amounts, stipulated, fidel, platters, another,
# Average loss at step 32000: 3.496601
# Average loss at step 34000: 3.499060
# Average loss at step 36000: 3.452766
# Average loss at step 38000: 3.299553
# Average loss at step 40000: 3.434546
# Nearest to has: had, have, was, is, having, autobahn, semite, heartfelt,
# Nearest to was: is, became, had, has, were, been, be, buddies,
# Nearest to there: they, it, he, she, still, often, now, these,
# Nearest to during: despite, after, until, before, at, in, seaman, economist,
# Nearest to american: british, australian, french, english, staffs, benefited, county, ers,
# Nearest to states: waco, countries, kingdom, nations, vanes, reuse, lackluster, habitability,
# Nearest to other: different, various, paphos, several, baptists, these, wiecino, many,
# Nearest to will: would, can, could, should, may, must, cannot, might,
# Nearest to after: before, during, when, from, until, miscellaneous, for, hormone,
# Nearest to while: when, though, generator, gauss, before, however, where, valved,
# Nearest to for: if, after, knowable, whistleblower, okavango, in, when, by,
# Nearest to many: some, several, these, various, both, all, most, augsburg,
# Nearest to and: or, but, in, flanagan, guez, when, gel, irina,
# Nearest to history: wafers, compaor, islamic, modern, median, bbbb, mercury, cleaners,
# Nearest to world: interference, antiarrhythmic, fib, u, economy, hydra, underlines, marmalade,
# Nearest to a: the, any, amounts, no, another, mctaggart, ecologist, or,
# Average loss at step 42000: 3.432369
# Average loss at step 44000: 3.454615
# Average loss at step 46000: 3.444383
# Average loss at step 48000: 3.353120
# Average loss at step 50000: 3.386415
# Nearest to has: had, have, was, is, having, autobahn, heartfelt, since,
# Nearest to was: is, were, became, has, had, been, being, remains,
# Nearest to there: it, they, he, she, now, still, often, chromatography,
# Nearest to during: after, despite, in, at, until, before, from, economist,
# Nearest to american: british, australian, english, staffs, international, french, italian, gernsback,
# Nearest to states: kingdom, waco, nations, countries, vanes, disclose, lackluster, merseyside,
# Nearest to other: different, various, paphos, many, these, baptists, several, some,
# Nearest to will: would, could, can, should, may, might, must, does,
# Nearest to after: before, when, during, but, until, hormone, while, from,
# Nearest to while: when, though, however, but, although, where, before, after,
# Nearest to for: removing, while, knowable, on, petersen, against, utility, following,
# Nearest to many: some, several, both, these, various, numerous, those, few,
# Nearest to and: or, but, including, than, signage, s, ayrshire, of,
# Nearest to history: list, mercury, lengthy, islamic, compaor, modern, wafers, cessna,
# Nearest to world: interference, ampex, fib, u, hydra, antiarrhythmic, economy, philadelphia,
# Nearest to a: any, the, amounts, giotto, berkelium, another, formants, discourage,
# Average loss at step 52000: 3.438491
# Average loss at step 54000: 3.423952
# Average loss at step 56000: 3.436007
# Average loss at step 58000: 3.400521
# Average loss at step 60000: 3.396093
# Nearest to has: had, have, was, is, having, autobahn, although, contains,
# Nearest to was: is, had, became, were, has, be, although, been,
# Nearest to there: they, it, now, she, he, still, often, this,
# Nearest to during: after, despite, before, in, at, until, within, following,
# Nearest to american: british, australian, english, staffs, international, french, italian, fixtures,
# Nearest to states: kingdom, nations, countries, waco, vanes, lackluster, us, territory,
# Nearest to other: various, different, many, several, some, including, paphos, older,
# Nearest to will: would, could, can, may, should, must, might, does,
# Nearest to after: before, during, when, while, until, hormone, despite, although,
# Nearest to while: when, although, before, though, after, however, where, randal,
# Nearest to for: of, following, if, although, in, or, after, removing,
# Nearest to many: some, several, various, both, these, most, numerous, other,
# Nearest to and: or, but, although, including, in, than, signage, razor,
# Nearest to history: consists, list, culture, historical, demographics, wafers, modern, gorges,
# Nearest to world: interference, u, fib, marmalade, antiarrhythmic, movement, philadelphia, underlines,
# Nearest to a: any, another, the, every, amounts, lew, cobra, rainer,
# Average loss at step 62000: 3.244269
# Average loss at step 64000: 3.257758
# Average loss at step 66000: 3.401172
# Average loss at step 68000: 3.394239
# Average loss at step 70000: 3.357317
# Nearest to has: had, have, is, was, since, autobahn, having, contains,
# Nearest to was: is, were, had, has, became, been, when, rpp,
# Nearest to there: they, it, she, he, still, now, often, this,
# Nearest to during: after, before, despite, until, throughout, in, within, at,
# Nearest to american: australian, british, staffs, italian, english, fixtures, canadian, international,
# Nearest to states: kingdom, nations, countries, waco, vanes, kops, us, assr,
# Nearest to other: various, different, including, many, some, stores, physical, such,
# Nearest to will: would, could, may, can, should, must, might, cannot,
# Nearest to after: before, during, when, despite, while, until, for, although,
# Nearest to while: although, though, however, when, before, but, after, where,
# Nearest to for: after, without, foldoc, in, by, petersen, dusseldorf, to,
# Nearest to many: some, several, various, these, both, all, most, numerous,
# Nearest to and: or, but, which, while, of, however, bauxite, both,
# Nearest to history: list, culture, consists, portion, origins, period, serbia, course,
# Nearest to world: u, interference, underlines, ampex, covent, fricatives, antiarrhythmic, significand,
# Nearest to a: the, another, any, amounts, stoker, its, enough, this,
# Average loss at step 72000: 3.379088
# Average loss at step 74000: 3.344103
# Average loss at step 76000: 3.324967
# Average loss at step 78000: 3.351469
# Average loss at step 80000: 3.379735
# Nearest to has: had, have, is, was, although, having, autobahn, since,
# Nearest to was: is, became, were, had, has, being, remains, been,
# Nearest to there: it, they, he, she, now, still, we, often,
# Nearest to during: after, throughout, before, until, despite, in, within, when,
# Nearest to american: british, australian, italian, canadian, fixtures, speciality, staffs, western,
# Nearest to states: kingdom, nations, countries, us, territory, arab, waco, diaconate,
# Nearest to other: various, including, many, several, different, older, some, unscientific,
# Nearest to will: would, could, can, should, may, must, might, cannot,
# Nearest to after: before, when, during, despite, while, until, though, following,
# Nearest to while: although, though, when, after, however, but, before, or,
# Nearest to for: after, in, when, exerted, foldoc, abstain, although, bidder,
# Nearest to many: some, several, various, these, numerous, most, both, all,
# Nearest to and: or, but, rafe, while, theoretician, including, quinn, jess,
# Nearest to history: list, origins, culture, taxon, islamic, philosophy, consists, period,
# Nearest to world: interference, u, ampex, underlines, covent, branson, riverboat, antiarrhythmic,
# Nearest to a: another, the, stoker, any, enough, earns, every, giotto,
# Average loss at step 82000: 3.411186
# Average loss at step 84000: 3.412945
# Average loss at step 86000: 3.389302
# Average loss at step 88000: 3.350424
# Average loss at step 90000: 3.367817
# Nearest to has: had, have, is, was, having, since, although, autobahn,
# Nearest to was: is, had, became, were, has, be, been, remains,
# Nearest to there: they, it, she, he, now, we, still, usually,
# Nearest to during: after, until, throughout, despite, in, before, within, while,
# Nearest to american: british, australian, canadian, italian, french, german, fixtures, seattle,
# Nearest to states: kingdom, nations, us, countries, territory, arab, kops, waco,
# Nearest to other: various, individual, including, different, many, paphos, physical, several,
# Nearest to will: would, could, can, should, must, may, might, cannot,
# Nearest to after: before, when, during, while, despite, until, for, if,
# Nearest to while: although, when, though, before, after, during, were, however,
# Nearest to for: including, of, during, after, chloroplast, mai, following, against,
# Nearest to many: some, several, various, these, numerous, most, all, both,
# Nearest to and: or, but, including, expressionist, bavarian, through, however, while,
# Nearest to history: list, culture, salinas, portion, museum, islamic, taxon, consists,
# Nearest to world: interference, underlines, ampex, existed, u, covent, borrowing, thayer,
# Nearest to a: any, the, another, earns, stoker, fontane, formants, every,
# Average loss at step 92000: 3.397843
# Average loss at step 94000: 3.260456
# Average loss at step 96000: 3.361368
# Average loss at step 98000: 3.243984
# Average loss at step 100000: 3.363965
# Nearest to has: had, have, is, was, having, since, autobahn, contains,
# Nearest to was: is, became, were, had, has, been, matchbox, being,
# Nearest to there: they, he, it, now, she, we, generally, often,
# Nearest to during: despite, throughout, after, until, in, at, before, since,
# Nearest to american: british, canadian, italian, australian, arnold, french, speciality, fiasco,
# Nearest to states: nations, kingdom, countries, us, arab, kops, territory, compass,
# Nearest to other: various, individual, others, older, including, different, stores, wiecino,
# Nearest to will: would, can, could, should, may, must, might, cannot,
# Nearest to after: before, when, during, despite, while, although, without, until,
# Nearest to while: although, when, before, though, after, and, but, where,
# Nearest to for: when, after, against, chloroplast, during, if, before, emulation,
# Nearest to many: several, some, various, these, numerous, all, few, certain,
# Nearest to and: or, but, while, when, however, although, including, posterity,
# Nearest to history: list, salinas, consists, culture, portion, reisman, apec, origins,
# Nearest to world: interference, u, ampex, underlines, borrowing, fricatives, robbing, alhazen,
# Nearest to a: any, another, the, khazaria, enough, franconian, lew, amounts,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
def generate_batch_cbow(batch_size, skip_window):
    # skip window is the amount of words we're looking at from each side of a given word
    # creates a single batch
    global data_index
 
    span = 2 * skip_window + 1 # [ skip_window target skip_window ]
 
    batch = np.ndarray(shape=(batch_size,span-1), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    # e.g if skip_window = 2 then span = 5
    # span is the length of the whole frame we are considering for a single word (left + word + right)
    # skip_window is the length of one side
 
    # queue which add and pop at the end
    buffer = collections.deque(maxlen=span)
 
    #get words starting from index 0 to span
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
 
    for i in range(batch_size):
        target = skip_window  # target label at the center of the buffer
        target_to_avoid = [ skip_window ] # we only need to know the words around a given word, not the word itself
 
        col_idx = 0
        for j in range(span):
            if j==span//2:
                continue
            batch[i,col_idx] = buffer[j] # [skip_window] => middle element
            col_idx += 1
        labels[i, 0] = buffer[target]
 
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
 
    assert batch.shape[0]==batch_size and batch.shape[1]== span-1
    return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch_cbow(batch_size=8, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('   batch:', [[reverse_dictionary[i] for i in bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#    batch: [['anarchism', 'as'], ['originated', 'a'], ['as', 'term'], ['a', 'of'], ['term', 'abuse'], ['of', 'first'], ['abuse', 'used'], ['first', 'against']]
#     labels: ['originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used']
#
# with num_skips = 4 and skip_window = 2:
#    batch: [['anarchism', 'originated', 'a', 'term'], ['originated', 'as', 'term', 'of'], ['as', 'a', 'of', 'abuse'], ['a', 'term', 'abuse', 'first'], ['term', 'of', 'first', 'used'], ['of', 'abuse', 'used', 'against'], ['abuse', 'first', 'against', 'early'], ['first', 'used', 'early', 'working']]
#     labels: ['as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size, 2*skip_window])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Averaging embeddings accross the full context into a single embedding layer
  context_embeddings = []
  for i in range(2*skip_window):
      context_embeddings.append(tf.nn.embedding_lookup(embeddings, train_dataset[:,i]))

  avg_embed =  tf.reduce_mean(tf.stack(axis=0,values=context_embeddings),0,keep_dims=False)
    
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=avg_embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch_cbow(
      batch_size, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.511932
# Nearest to have: nance, feats, superintendents, pickups, fra, bartleby, supple, moguls,
# Nearest to on: caller, dalhousie, appeasement, sterne, dench, ermine, sava, diego,
# Nearest to world: hariri, ooze, homeworld, chuan, hosni, dylan, emma, leased,
# Nearest to it: assault, brush, hegelian, venice, sprung, perennially, quantized, presbyterian,
# Nearest to i: siddha, hbp, peyton, lovingly, amanda, spink, xxxv, bookkeeping,
# Nearest to has: daughter, nitrite, olam, syndicalist, leaking, sow, calculator, circumnavigation,
# Nearest to a: mathcal, reveal, cores, owens, armenians, bob, garnet, propyl,
# Nearest to and: vaults, accesses, gifts, cip, todd, erased, foundation, my,
# Nearest to many: thanking, flies, anaheim, sinbad, yyyy, fallacious, englewood, kanal,
# Nearest to they: chicagoans, hyginus, methodological, stripe, disciplinarian, trinitarian, oceans, legs,
# Nearest to of: overtly, lend, attainder, oro, overlapping, turned, gana, cinematic,
# Nearest to nine: skin, exceptional, arp, lockwood, fieldwork, restated, wuhan, hdz,
# Nearest to can: nell, civilian, xv, minicomputers, shear, armas, dartmoor, miao,
# Nearest to as: threatened, chatter, astrolabe, ecosystems, betty, rahilly, nashwaak, tian,
# Nearest to during: believes, prince, orgasm, perverse, flickr, projections, monarchy, milhaud,
# Nearest to eight: pervading, customs, fretted, uzbekistan, surfer, spline, allying, rumford,
# Average loss at step 2000: 4.037860
# Average loss at step 4000: 3.504326
# Average loss at step 6000: 3.341643
# Average loss at step 8000: 3.191087
# Average loss at step 10000: 3.144092
# Nearest to have: had, be, has, nance, pickups, popeye, disappeared, psychosocial,
# Nearest to on: caller, into, in, falklands, correct, under, diego, against,
# Nearest to world: leased, hariri, bucks, emma, akkadian, moesia, ooze, ennius,
# Nearest to it: he, this, she, there, they, fullness, pants, pathology,
# Nearest to i: siddha, breads, lovingly, earthquake, bremen, they, sampson, dragoon,
# Nearest to has: was, had, is, have, became, calculator, if, although,
# Nearest to a: the, kj, pratyeka, its, favours, cores, another, petit,
# Nearest to and: or, but, peyote, d, lobbyist, payoff, my, aspire,
# Nearest to many: some, several, these, confederation, anaheim, fallacious, iigs, all,
# Nearest to they: he, we, there, she, you, it, i, subcode,
# Nearest to of: during, overtly, cajun, miscible, sayer, in, cinematic, sage,
# Nearest to nine: eight, six, seven, five, four, three, zero, two,
# Nearest to can: will, may, could, would, should, must, might, durango,
# Nearest to as: jamil, german, alley, rahilly, leaked, pickled, invertebrates, chatter,
# Nearest to during: in, best, of, frits, against, blower, clutching, casein,
# Nearest to eight: nine, six, four, five, seven, three, zero, two,
# Average loss at step 12000: 3.169520
# Average loss at step 14000: 3.126079
# Average loss at step 16000: 3.145833
# Average loss at step 18000: 3.104798
# Average loss at step 20000: 2.990413
# Nearest to have: had, has, were, be, are, popeye, newsstand, represent,
# Nearest to on: upon, caller, around, falklands, correct, lymphedema, in, under,
# Nearest to world: leased, emma, devious, bucks, chu, hariri, akkadian, sarris,
# Nearest to it: he, this, she, there, they, brush, demoness, pants,
# Nearest to i: they, siddha, he, breads, lovingly, smear, dragoon, bremen,
# Nearest to has: had, have, was, is, became, calculator, posited, kurukshetra,
# Nearest to a: the, kj, every, pratyeka, any, another, druyan, cores,
# Nearest to and: or, but, barium, constructor, clothed, putney, caldera, carducci,
# Nearest to many: some, several, these, confederation, those, iigs, fallacious, most,
# Nearest to they: we, he, you, there, she, i, it, subcode,
# Nearest to of: overtly, basalt, karamazov, facie, heapsort, miscible, during, include,
# Nearest to nine: eight, six, seven, four, zero, five, three, two,
# Nearest to can: will, may, could, would, must, should, might, shall,
# Nearest to as: jamil, blatantly, rahilly, pickled, tore, buyout, when, doubles,
# Nearest to during: in, best, before, against, frits, by, from, until,
# Nearest to eight: six, seven, nine, four, five, three, zero, two,
# Average loss at step 22000: 3.060079
# Average loss at step 24000: 3.024580
# Average loss at step 26000: 2.990390
# Average loss at step 28000: 3.015915
# Average loss at step 30000: 2.986677
# Nearest to have: had, has, are, were, represent, newsstand, be, popeye,
# Nearest to on: upon, around, falklands, caller, in, lymphedema, through, magnet,
# Nearest to world: leased, emma, misunderstanding, moesia, hosni, sarris, longest, devious,
# Nearest to it: he, she, this, there, they, pants, equal, timber,
# Nearest to i: they, siddha, smear, you, note, fenrir, dragoon, pointless,
# Nearest to has: had, have, was, is, having, kurukshetra, became, ojibwa,
# Nearest to a: another, the, pratyeka, any, kj, every, helmet, brenner,
# Nearest to and: or, but, elsevier, aegean, including, asleep, digging, parrish,
# Nearest to many: some, several, these, various, most, those, fallacious, other,
# Nearest to they: we, he, you, there, she, it, these, i,
# Nearest to of: basalt, miscible, include, overtly, anions, where, directory, basic,
# Nearest to nine: eight, seven, six, four, five, three, two, zero,
# Nearest to can: will, may, could, would, must, should, might, shall,
# Nearest to as: jamil, blatantly, leaked, pickled, rahilly, buyout, qx, tian,
# Nearest to during: in, before, after, against, at, frits, pursuant, through,
# Nearest to eight: nine, six, seven, four, five, three, zero, two,
# Average loss at step 32000: 2.842416
# Average loss at step 34000: 2.950943
# Average loss at step 36000: 2.936624
# Average loss at step 38000: 2.940548
# Average loss at step 40000: 2.919848
# Nearest to have: had, has, were, are, represent, be, newsstand, mellitus,
# Nearest to on: upon, caller, falklands, around, lymphedema, through, correct, stagecoach,
# Nearest to world: leased, emma, moesia, misunderstanding, daoxuan, longest, veronica, microvision,
# Nearest to it: he, she, there, this, they, pants, relaxing, timber,
# Nearest to i: ii, you, they, rex, fenrir, smear, pointless, we,
# Nearest to has: had, have, was, is, having, kurukshetra, ojibwa, heighten,
# Nearest to a: another, pratyeka, kj, barks, salvadoran, the, enough, every,
# Nearest to and: or, but, nominates, while, quadruple, handicrafts, digging, parrish,
# Nearest to many: some, several, most, various, all, these, those, confederation,
# Nearest to they: we, he, you, there, she, it, soon, who,
# Nearest to of: overtly, motocross, include, americium, lucrezia, facie, infidels, rodham,
# Nearest to nine: eight, seven, six, four, five, three, zero, two,
# Nearest to can: may, will, could, would, must, might, should, cannot,
# Nearest to as: rahilly, jamil, blatantly, sada, when, moa, benny, qx,
# Nearest to during: in, after, before, from, through, giga, against, at,
# Nearest to eight: nine, seven, six, four, five, three, zero, two,
# Average loss at step 42000: 2.938860
# Average loss at step 44000: 2.945235
# Average loss at step 46000: 2.904602
# Average loss at step 48000: 2.865390
# Average loss at step 50000: 2.837889
# Nearest to have: had, has, are, were, represent, mellitus, require, popeye,
# Nearest to on: upon, caller, falklands, around, in, lymphedema, correct, through,
# Nearest to world: leased, emma, country, moesia, daoxuan, misunderstanding, longest, tactics,
# Nearest to it: he, she, there, this, they, which, relaxing, what,
# Nearest to i: you, ii, we, compilers, lpc, rex, pointless, g,
# Nearest to has: had, have, is, was, having, kurukshetra, heighten, includes,
# Nearest to a: the, another, kj, pratyeka, kelp, any, salvadoran, amounts,
# Nearest to and: or, but, including, while, unify, versus, although, headlines,
# Nearest to many: some, several, most, various, these, all, fallacious, confederation,
# Nearest to they: we, he, there, you, she, it, soon, these,
# Nearest to of: overtly, heapsort, basalt, lucrezia, including, lads, loneliness, riley,
# Nearest to nine: eight, seven, six, four, five, three, zero, two,
# Nearest to can: may, will, could, must, would, might, should, cannot,
# Nearest to as: jamil, rahilly, blatantly, tian, pickled, moa, dreamlike, richman,
# Nearest to during: in, after, before, at, from, within, giga, through,
# Nearest to eight: nine, seven, six, four, five, three, zero, two,
# Average loss at step 52000: 2.879586
# Average loss at step 54000: 2.859996
# Average loss at step 56000: 2.861070
# Average loss at step 58000: 2.760478
# Average loss at step 60000: 2.824447
# Nearest to have: had, has, were, are, represent, having, require, be,
# Nearest to on: upon, caller, falklands, around, in, through, under, lymphedema,
# Nearest to world: emma, leased, country, tactics, vietnam, moesia, veronica, devious,
# Nearest to it: he, she, this, there, they, what, grammatically, relaxing,
# Nearest to i: you, ii, we, g, they, rex, remixing, he,
# Nearest to has: had, have, was, is, having, kurukshetra, includes, provides,
# Nearest to a: kj, pratyeka, another, the, amounts, vulnerability, enough, any,
# Nearest to and: or, but, although, while, drifted, which, carducci, including,
# Nearest to many: some, several, various, most, all, these, those, numerous,
# Nearest to they: we, he, you, there, she, it, ultimately, soon,
# Nearest to of: anions, basalt, include, americium, including, karamazov, guessed, despite,
# Nearest to nine: eight, seven, six, five, four, three, zero, one,
# Nearest to can: may, could, will, must, would, should, might, cannot,
# Nearest to as: rahilly, jamil, periodicals, tian, blatantly, leaked, qx, richman,
# Nearest to during: in, after, within, at, before, when, through, until,
# Nearest to eight: nine, six, seven, four, five, three, zero, two,
# Average loss at step 62000: 2.830504
# Average loss at step 64000: 2.777891
# Average loss at step 66000: 2.768034
# Average loss at step 68000: 2.719002
# Average loss at step 70000: 2.776075
# Nearest to have: had, has, were, are, represent, require, be, having,
# Nearest to on: upon, in, falklands, under, caller, around, through, lymphedema,
# Nearest to world: club, country, vietnam, tactics, emma, lascaux, reception, withhold,
# Nearest to it: he, she, there, this, they, relaxing, pants, itself,
# Nearest to i: you, ii, we, remixing, pointless, g, rex, they,
# Nearest to has: had, have, is, was, kurukshetra, having, makes, ojibwa,
# Nearest to a: another, any, kj, pratyeka, every, the, enough, barks,
# Nearest to and: or, but, while, although, drysdale, carducci, including, nominates,
# Nearest to many: some, several, various, most, numerous, those, these, all,
# Nearest to they: we, he, there, you, she, it, these, ultimately,
# Nearest to of: lucrezia, in, across, guessed, riley, heapsort, concerning, facie,
# Nearest to nine: eight, seven, six, five, four, three, zero, two,
# Nearest to can: could, may, will, must, would, should, might, cannot,
# Nearest to as: rahilly, blatantly, moa, richman, jamil, lovelace, ripken, sada,
# Nearest to during: in, after, within, at, before, when, until, although,
# Nearest to eight: seven, six, nine, five, four, three, zero, two,
# Average loss at step 72000: 2.798806
# Average loss at step 74000: 2.656210
# Average loss at step 76000: 2.798446
# Average loss at step 78000: 2.823567
# Average loss at step 80000: 2.779983
# Nearest to have: had, has, were, are, represent, require, mellitus, having,
# Nearest to on: upon, falklands, through, in, under, around, caller, lymphedema,
# Nearest to world: vietnam, country, lascaux, tactics, veronica, receiver, emma, u,
# Nearest to it: he, she, there, this, they, today, itself, relaxing,
# Nearest to i: you, we, they, ii, pointless, she, remixing, att,
# Nearest to has: had, have, was, is, having, kurukshetra, ojibwa, includes,
# Nearest to a: another, pratyeka, kj, barks, every, borrowings, earnest, any,
# Nearest to and: or, but, parrish, including, eastman, although, putney, headlines,
# Nearest to many: several, some, various, numerous, most, all, those, both,
# Nearest to they: we, he, you, there, she, it, i, dehydrogenase,
# Nearest to of: facie, lucrezia, guessed, across, heapsort, riley, concerning, inmarsat,
# Nearest to nine: eight, seven, six, five, four, three, zero, two,
# Nearest to can: could, may, will, must, would, should, might, cannot,
# Nearest to as: rahilly, sada, jamil, tian, moa, nashwaak, milah, when,
# Nearest to during: in, after, when, before, at, within, until, although,
# Nearest to eight: six, nine, seven, five, four, three, two, zero,
# Average loss at step 82000: 2.671580
# Average loss at step 84000: 2.773491
# Average loss at step 86000: 2.742951
# Average loss at step 88000: 2.758739
# Average loss at step 90000: 2.739156
# Nearest to have: had, has, were, are, represent, mellitus, require, having,
# Nearest to on: upon, in, falklands, through, around, under, caller, at,
# Nearest to world: country, vietnam, tactics, lascaux, shopping, reception, leased, u,
# Nearest to it: he, she, there, this, they, today, grammatically, ultimately,
# Nearest to i: you, we, ii, they, pointless, att, she, he,
# Nearest to has: had, have, is, was, kurukshetra, having, includes, pornographic,
# Nearest to a: another, pratyeka, kj, enough, the, barks, amounts, earnest,
# Nearest to and: or, but, including, although, incur, nominates, parrish, versus,
# Nearest to many: some, several, various, numerous, most, those, all, both,
# Nearest to they: we, he, you, there, she, it, i, these,
# Nearest to of: concerning, infidels, lucrezia, inmarsat, guessed, anions, miscible, facing,
# Nearest to nine: eight, seven, six, four, five, three, two, zero,
# Nearest to can: could, will, would, may, must, should, might, cannot,
# Nearest to as: rahilly, moa, richman, tian, blatantly, jamil, including, crooked,
# Nearest to during: in, after, before, at, when, within, although, under,
# Nearest to eight: seven, six, nine, four, five, three, two, zero,
# Average loss at step 92000: 2.689214
# Average loss at step 94000: 2.724266
# Average loss at step 96000: 2.709758
# Average loss at step 98000: 2.381935
# Average loss at step 100000: 2.423707
# Nearest to have: had, has, are, were, represent, having, require, mellitus,
# Nearest to on: upon, falklands, through, around, in, caller, lymphedema, neutrinos,
# Nearest to world: vietnam, daoxuan, tactics, lascaux, pursuing, receiver, reception, withhold,
# Nearest to it: he, she, there, they, this, ultimately, itself, soon,
# Nearest to i: you, we, ii, pointless, att, they, she, rex,
# Nearest to has: had, have, is, was, kurukshetra, having, pornographic, bathing,
# Nearest to a: barks, another, pratyeka, kj, the, erskine, borrowings, albeit,
# Nearest to and: or, but, swnts, panth, although, nominates, including, philippe,
# Nearest to many: several, some, various, numerous, those, most, all, both,
# Nearest to they: we, he, there, you, she, it, hardly, ultimately,
# Nearest to of: lucrezia, guessed, cinematic, riley, sage, anions, infidels, describes,
# Nearest to nine: eight, seven, six, four, five, three, zero, two,
# Nearest to can: could, will, must, would, should, may, might, cannot,
# Nearest to as: rahilly, blatantly, tian, gutrune, telling, qx, moa, calamine,
# Nearest to during: in, at, after, when, before, despite, within, under,
# Nearest to eight: nine, seven, six, four, five, three, two, zero,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
