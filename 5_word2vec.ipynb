# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %%
words[:15]
# Out:
# ['anarchism',
#  'originated',
#  'as',
#  'a',
#  'term',
#  'of',
#  'abuse',
#  'first',
#  'used',
#  'against',
#  'early',
#  'working',
#  'class',
#  'radicals',
#  'including']

# %% [markdown]
# Build the dictionary and replace rare words with UNK token. We simply calculate here the number of words we meet in words.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:10])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764), ('in', 372201), ('a', 325873), ('to', 316376), ('zero', 264975), ('nine', 250430)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'a', 'originated', 'as', 'term', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['originated', 'term', 'anarchism', 'a', 'term', 'originated', 'as', 'of']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %% [markdown]
# Each step:
#
# 1. Generate minibatch with size 128: batch size = 128, batch labels = 128
# 2. feed_dict constructs a dictionary for train dataset and train labels
# 3. session.run passes to training defined above

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.910026
# Nearest to more: crystalline, brin, electrochemical, oxygenated, conjectural, beneficiary, homeomorphisms, denotation,
# Nearest to not: bacillus, p, subgenre, encyclopedist, speyer, meir, obesity, destiny,
# Nearest to and: debunked, surveyed, mistake, respectfully, questionable, wardens, sade, corba,
# Nearest to but: buddhas, something, mjd, sindhu, cola, ackermann, negligent, malicious,
# Nearest to by: luoyang, autostrada, deutscher, nihon, baccalaureate, sucked, peers, imo,
# Nearest to or: cytoskeleton, enlist, damme, gokturk, lombardo, collegiate, venturi, longman,
# Nearest to seven: reprisals, rudimentary, investigators, luoyang, exocet, exhibition, hip, mysterious,
# Nearest to people: viper, unselfish, amiens, hostels, paved, rusting, bodhidharma, mosfet,
# Nearest to as: exacted, hideout, engineered, inspection, ccds, screenplays, precedes, reliance,
# Nearest to his: interpolations, scale, cracow, hiring, aesthetic, generalitat, puerto, disappearances,
# Nearest to only: mosque, dirichlet, dad, minimizes, divide, bale, callisto, tunable,
# Nearest to i: charities, azeglio, florid, thirsty, fyodor, malls, burger, holocaust,
# Nearest to d: bottleneck, lux, fierce, hint, jujutsu, rez, specialises, burkina,
# Nearest to from: constans, blissymbolics, piso, casualty, courtyards, extermination, lahr, pilots,
# Nearest to states: undefeated, rida, parry, resumes, suspected, nicomachean, content, dps,
# Nearest to history: vittorio, elision, moo, fielded, incorrectly, munch, limerick, archbishop,
# Average loss at step 2000: 4.368394
# Average loss at step 4000: 3.859153
# Average loss at step 6000: 3.785910
# Average loss at step 8000: 3.682322
# Average loss at step 10000: 3.612796
# Nearest to more: oxygenated, electrochemical, brin, depletion, mall, indirect, slightly, denotation,
# Nearest to not: they, it, bacillus, also, hom, there, still, usually,
# Nearest to and: or, rebuke, who, whipple, s, under, american, like,
# Nearest to but: buddhas, see, sindhu, something, zap, although, ackermann, raw,
# Nearest to by: was, indra, been, with, baccalaureate, as, alternately, ssy,
# Nearest to or: and, spaghetti, reminding, jagiellonian, ateneo, hot, unsound, cumulative,
# Nearest to seven: three, eight, six, five, nine, four, zero, two,
# Nearest to people: viper, bodhidharma, eac, anarchism, unselfish, sfg, diatoms, diffeomorphism,
# Nearest to as: ivanovich, berenguer, by, unspecific, eugenics, follower, ehud, doughnut,
# Nearest to his: their, its, the, her, s, pungent, shame, musics,
# Nearest to only: dirichlet, spat, mosque, callisto, remnant, desolate, tunable, infringement,
# Nearest to i: charities, fyodor, camillo, anticipation, malls, he, spartan, rearden,
# Nearest to d: b, fierce, hemophilia, da, specialises, card, cathedrals, soy,
# Nearest to from: in, into, lymphedema, drama, chaffee, with, sticky, hannity,
# Nearest to states: groups, deliberations, grant, confines, nicomachean, fab, tha, compassionate,
# Nearest to history: vittorio, filming, sandalwood, moo, porta, prat, centres, limerick,
# Average loss at step 12000: 3.606015
# Average loss at step 14000: 3.572318
# Average loss at step 16000: 3.400237
# Average loss at step 18000: 3.457036
# Average loss at step 20000: 3.539639
# Nearest to more: most, very, oxygenated, electrochemical, depletion, indirect, minimise, slightly,
# Nearest to not: they, to, usually, also, never, it, bacillus, still,
# Nearest to and: or, who, in, from, questionable, which, optimized, at,
# Nearest to but: is, which, however, although, that, never, murphy, does,
# Nearest to by: be, nonviolence, with, through, for, in, at, is,
# Nearest to or: and, spaghetti, than, jagiellonian, siegel, lorna, wct, ternary,
# Nearest to seven: eight, six, nine, three, five, four, zero, two,
# Nearest to people: viper, areas, diffeomorphism, eac, pron, owners, anarchism, quaternary,
# Nearest to as: berenguer, precedes, follower, spaghetti, eugenics, courageous, absolutely, hobson,
# Nearest to his: their, her, its, the, my, pronunciation, craton, harappa,
# Nearest to only: spat, dirichlet, callisto, never, infringement, orbison, hom, directly,
# Nearest to i: ii, charities, camillo, welsh, fyodor, basins, we, remarried,
# Nearest to d: b, da, hemophilia, card, valet, specialises, soy, numeration,
# Nearest to from: in, at, into, through, hormonal, chaffee, and, midwife,
# Nearest to states: confines, deliberations, charlottetown, compassionate, groups, pigment, grant, vfa,
# Nearest to history: sandalwood, kary, centres, elision, prat, cadr, filming, vittorio,
# Average loss at step 22000: 3.501667
# Average loss at step 24000: 3.490793
# Average loss at step 26000: 3.485083
# Average loss at step 28000: 3.478026
# Average loss at step 30000: 3.505311
# Nearest to more: less, most, very, electrochemical, indirect, permafrost, minimise, estudios,
# Nearest to not: they, still, routinely, there, bacillus, never, dey, therefore,
# Nearest to and: or, but, in, of, who, from, infty, barbarism,
# Nearest to but: however, although, and, which, though, when, he, misspelling,
# Nearest to by: under, were, in, apcs, with, longed, as, indra,
# Nearest to or: and, lorna, spaghetti, jagiellonian, philosophiae, wct, soaemias, carotenoids,
# Nearest to seven: four, eight, nine, five, six, three, zero, two,
# Nearest to people: languages, viper, areas, diffeomorphism, gottorp, children, anarchism, bodhidharma,
# Nearest to as: by, italia, in, absolutely, plundered, cthulhu, follower, courageous,
# Nearest to his: their, her, the, its, my, s, pronunciation, bribed,
# Nearest to only: reductionism, directly, hom, dreadful, orbison, too, infringement, never,
# Nearest to i: ii, we, fyodor, iii, charities, basins, discharged, anticipation,
# Nearest to d: b, fierce, da, grantley, hemophilia, macbeth, cathedrals, hermaphroditus,
# Nearest to from: into, of, in, since, partaking, between, and, lymphedema,
# Nearest to states: kingdom, pigment, deliberations, confines, groups, vfa, nominee, nations,
# Nearest to history: sandalwood, filming, centres, kary, prat, psionic, vittorio, porta,
# Average loss at step 32000: 3.498416
# Average loss at step 34000: 3.492860
# Average loss at step 36000: 3.456062
# Average loss at step 38000: 3.305461
# Average loss at step 40000: 3.423259
# Nearest to more: less, most, very, other, electrochemical, estudios, mundar, higher,
# Nearest to not: never, they, therefore, usually, still, often, also, routinely,
# Nearest to and: or, but, like, optimized, jagiellonian, tak, in, wrest,
# Nearest to but: however, although, and, when, frequently, like, though, currently,
# Nearest to by: with, cache, longed, revealing, proportionality, when, from, through,
# Nearest to or: and, than, jagiellonian, nobleman, reminding, philosophiae, spaghetti, rameses,
# Nearest to seven: six, eight, five, nine, four, three, zero, two,
# Nearest to people: children, languages, men, gottorp, tariff, safeguard, retrospectively, anarchism,
# Nearest to as: absolutely, reciprocate, exacted, mathias, be, mature, bellini, santo,
# Nearest to his: their, her, its, the, my, drenched, s, superficial,
# Nearest to only: reductionism, hom, abnormally, infringement, no, never, chosen, okay,
# Nearest to i: ii, we, you, iii, t, g, cheddar, he,
# Nearest to d: b, fierce, da, tagline, percy, UNK, numeration, card,
# Nearest to from: through, into, between, since, lymphedema, reenactment, of, magnus,
# Nearest to states: kingdom, nations, groups, pigment, vfa, christians, nominee, deliberations,
# Nearest to history: kary, centres, list, sandalwood, lorraine, prat, finely, psionic,
# Average loss at step 42000: 3.438310
# Average loss at step 44000: 3.457386
# Average loss at step 46000: 3.453059
# Average loss at step 48000: 3.356750
# Average loss at step 50000: 3.385222
# Nearest to more: less, most, very, higher, larger, smaller, soo, elsinore,
# Nearest to not: never, routinely, they, still, considered, usually, now, therefore,
# Nearest to and: or, but, however, while, whereas, optimized, including, dreamt,
# Nearest to but: however, although, though, while, when, and, unless, where,
# Nearest to by: through, revealing, under, was, ecusa, polypeptides, europ, longed,
# Nearest to or: and, than, quetta, convents, vile, forget, putsch, matchbox,
# Nearest to seven: six, eight, nine, four, three, five, zero, two,
# Nearest to people: children, men, cases, areas, languages, arguments, players, jews,
# Nearest to as: became, angell, absolutely, looked, bellini, blackwell, arana, excepting,
# Nearest to his: their, her, its, my, the, drenched, comrie, harappa,
# Nearest to only: hom, orbison, never, mckinney, usually, best, until, reductionism,
# Nearest to i: ii, we, you, t, iii, g, cheddar, jolley,
# Nearest to d: b, da, numeration, fierce, card, m, roamed, percy,
# Nearest to from: into, through, in, at, between, across, lymphedema, wct,
# Nearest to states: kingdom, nations, groups, deliberations, vfa, fab, exemplify, christians,
# Nearest to history: list, lorraine, maryland, centres, sandalwood, fannish, kary, versions,
# Average loss at step 52000: 3.435114
# Average loss at step 54000: 3.423430
# Average loss at step 56000: 3.437436
# Average loss at step 58000: 3.399037
# Average loss at step 60000: 3.392424
# Nearest to more: less, most, very, larger, smaller, rather, higher, better,
# Nearest to not: never, still, now, they, almost, usually, routinely, therefore,
# Nearest to and: or, but, than, while, converge, wct, provisionally, although,
# Nearest to but: however, and, although, though, currently, while, see, when,
# Nearest to by: through, longed, with, when, theobromine, cache, europ, ecusa,
# Nearest to or: and, than, prozac, polymer, characterizing, including, for, guido,
# Nearest to seven: eight, six, nine, four, five, three, zero, two,
# Nearest to people: men, children, players, those, safeguard, others, scholars, tariff,
# Nearest to as: absolutely, santo, miskelley, unaccustomed, became, cthulhu, ivanovich, excepting,
# Nearest to his: her, their, its, my, the, drenched, fittingly, your,
# Nearest to only: until, orbison, hom, okay, usually, never, reductionism, best,
# Nearest to i: ii, we, you, t, cheddar, iii, g, welsh,
# Nearest to d: b, h, m, da, roamed, numeration, p, j,
# Nearest to from: through, into, wct, in, magnus, since, lymphedema, goya,
# Nearest to states: kingdom, nations, groups, countries, vfa, confucianism, fab, christians,
# Nearest to history: list, bk, fannish, reign, philosophy, happily, cagney, disappointing,
# Average loss at step 62000: 3.239162
# Average loss at step 64000: 3.255960
# Average loss at step 66000: 3.401564
# Average loss at step 68000: 3.395111
# Average loss at step 70000: 3.359264
# Nearest to more: less, most, very, larger, smaller, rather, better, too,
# Nearest to not: never, now, still, almost, therefore, only, usually, generally,
# Nearest to and: or, while, like, but, including, dreamt, than, sas,
# Nearest to but: however, although, though, while, that, and, which, currently,
# Nearest to by: through, using, cache, longed, be, extremism, kota, in,
# Nearest to or: and, while, than, without, exhortations, like, matchbox, jagiellonian,
# Nearest to seven: eight, six, nine, four, five, three, two, zero,
# Nearest to people: men, children, players, women, safeguard, eclac, others, those,
# Nearest to as: coon, absolutely, looked, goran, eugenics, hobson, blackwell, cthulhu,
# Nearest to his: her, their, my, its, fittingly, drenched, schmidt, your,
# Nearest to only: hom, still, orbison, not, best, easily, until, celebratory,
# Nearest to i: ii, we, you, t, g, cheddar, wanna, vietnam,
# Nearest to d: b, da, h, roamed, m, p, percy, numeration,
# Nearest to from: through, into, lymphedema, reenactment, across, upon, magnus, viceroys,
# Nearest to states: kingdom, nations, countries, groups, state, sections, fab, bits,
# Nearest to history: list, reign, happily, sine, maryland, acquis, linebarger, disappointing,
# Average loss at step 72000: 3.378124
# Average loss at step 74000: 3.347261
# Average loss at step 76000: 3.311683
# Average loss at step 78000: 3.349856
# Average loss at step 80000: 3.376664
# Nearest to more: less, most, very, larger, smaller, quite, rather, higher,
# Nearest to not: still, always, never, generally, almost, usually, now, it,
# Nearest to and: or, while, but, tuvalu, including, dreamt, than, pit,
# Nearest to but: however, although, while, and, though, animist, see, jeremy,
# Nearest to by: longed, through, polypeptides, from, proportionality, scharnhorst, during, after,
# Nearest to or: and, while, than, characterizing, ringo, matchbox, carotenoids, aura,
# Nearest to seven: eight, six, five, four, nine, three, zero, two,
# Nearest to people: men, children, women, players, others, those, jews, teams,
# Nearest to as: absolutely, miskelley, chemotherapy, excepting, santo, coon, hag, unaccustomed,
# Nearest to his: her, their, its, my, the, enz, harappa, drenched,
# Nearest to only: orbison, best, hom, nameless, tolbert, until, celebratory, clauses,
# Nearest to i: ii, we, you, g, t, iii, cheddar, v,
# Nearest to d: b, h, da, roamed, tracing, m, trustedbsd, e,
# Nearest to from: through, into, across, lymphedema, between, during, by, midwife,
# Nearest to states: kingdom, nations, countries, confucianism, state, airstrips, vfa, groups,
# Nearest to history: list, happily, acquis, wave, cagney, rinks, illegally, reign,
# Average loss at step 82000: 3.410736
# Average loss at step 84000: 3.408199
# Average loss at step 86000: 3.385620
# Average loss at step 88000: 3.353497
# Average loss at step 90000: 3.361379
# Nearest to more: less, most, very, better, larger, too, rather, faster,
# Nearest to not: still, never, almost, always, now, tdi, therefore, it,
# Nearest to and: or, but, including, while, although, whereas, converge, wct,
# Nearest to but: however, and, although, though, while, which, that, they,
# Nearest to by: longed, through, with, during, using, under, extremism, revealing,
# Nearest to or: and, radix, while, though, characterizing, without, kamikaze, nuncio,
# Nearest to seven: eight, six, five, nine, four, three, zero, one,
# Nearest to people: men, children, women, players, jews, mishna, person, those,
# Nearest to as: excepting, coon, santo, blackwell, absolutely, disciplined, signatures, rips,
# Nearest to his: her, their, its, my, our, your, drenched, synchronized,
# Nearest to only: measured, no, alleviating, best, nothing, every, either, hom,
# Nearest to i: ii, we, g, you, t, v, iii, unsound,
# Nearest to d: b, pr, roamed, h, tracing, da, m, techno,
# Nearest to from: through, into, across, during, lymphedema, toward, between, magnus,
# Nearest to states: kingdom, nations, countries, us, principals, deliberations, state, vfa,
# Nearest to history: list, happily, illegally, reign, acquis, cagney, workplace, period,
# Average loss at step 92000: 3.398942
# Average loss at step 94000: 3.253805
# Average loss at step 96000: 3.357514
# Average loss at step 98000: 3.241665
# Average loss at step 100000: 3.358532
# Nearest to more: less, most, very, larger, better, greater, too, faster,
# Nearest to not: never, still, almost, they, always, now, generally, therefore,
# Nearest to and: or, but, like, while, although, including, when, who,
# Nearest to but: however, although, and, though, while, which, whereas, loneliness,
# Nearest to by: using, kota, longed, rien, when, through, caretaker, proportionality,
# Nearest to or: and, than, characterizing, while, polymer, though, hipparchus, doctorates,
# Nearest to seven: eight, nine, six, four, five, three, zero, two,
# Nearest to people: children, men, players, women, jews, individuals, countries, those,
# Nearest to as: absolutely, like, coon, excepting, screenplays, rips, claudian, signatures,
# Nearest to his: her, their, my, its, your, our, the, s,
# Nearest to only: measured, still, certainly, kremlin, until, scarcely, alleviating, orbison,
# Nearest to i: ii, we, you, t, v, iii, they, g,
# Nearest to d: b, grantley, h, c, october, daniell, numeration, pr,
# Nearest to from: through, across, into, in, reenactment, magnus, malik, slick,
# Nearest to states: kingdom, nations, us, countries, vfa, principals, state, groups,
# Nearest to history: list, acquis, happily, rinks, workplace, imhotep, lorraine, senegal,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
def generate_batch_cbow(batch_size, skip_window):
    # skip window is the amount of words we're looking at from each side of a given word
    # creates a single batch
    global data_index
 
    span = 2 * skip_window + 1 # [ skip_window target skip_window ]
 
    batch = np.ndarray(shape=(batch_size,span-1), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    # e.g if skip_window = 2 then span = 5
    # span is the length of the whole frame we are considering for a single word (left + word + right)
    # skip_window is the length of one side
 
    # queue which add and pop at the end
    buffer = collections.deque(maxlen=span)
 
    #get words starting from index 0 to span
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
 
    for i in range(batch_size):
        target = skip_window  # target label at the center of the buffer
        target_to_avoid = [ skip_window ] # we only need to know the words around a given word, not the word itself
 
        col_idx = 0
        for j in range(span):
            if j==span//2:
                continue
            batch[i,col_idx] = buffer[j] # [skip_window] => middle element
            col_idx += 1
        labels[i, 0] = buffer[target]
 
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
 
    assert batch.shape[0]==batch_size and batch.shape[1]== span-1
    return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch_cbow(batch_size=8, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('   batch:', [reverse_dictionary[i] for bi in batch for i in bi])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#    batch: ['anarchism', 'as', 'originated', 'a', 'as', 'term', 'a', 'of', 'term', 'abuse', 'of', 'first', 'abuse', 'used', 'first', 'against']
#     labels: ['originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used']
#
# with num_skips = 4 and skip_window = 2:
#    batch: ['anarchism', 'originated', 'a', 'term', 'originated', 'as', 'term', 'of', 'as', 'a', 'of', 'abuse', 'a', 'term', 'abuse', 'first', 'term', 'of', 'first', 'used', 'of', 'abuse', 'used', 'against', 'abuse', 'first', 'against', 'early', 'first', 'used', 'early', 'working']
#     labels: ['as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
valid_examples = np.append(valid_examples,random.sample(range(1000,1000+valid_window), valid_size//2))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size, 2*skip_window])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Averaging embeddings accross the full context into a single embedding layer
  context_embeddings = []
  for i in range(2*skip_window):
      context_embeddings.append(tf.nn.embedding_lookup(embeddings, train_dataset[:,i]))

  avg_embed =  tf.reduce_mean(tf.stack(axis=0,values=context_embeddings),0,keep_dims=False)
    
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=avg_embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch_cbow(
      batch_size, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.657867
# Nearest to called: nominates, leonhard, broken, gunto, ore, borax, chang, microphone,
# Nearest to these: cauldron, palmerston, roost, ib, deformation, talents, electronegative, icftu,
# Nearest to six: niall, prisms, threaded, optimistic, angered, consumed, relating, seditious,
# Nearest to of: covenant, colors, amongst, attempt, accounted, alphabets, budgeted, balliol,
# Nearest to see: fascists, mapmaking, cuthbert, contagion, corticosteroids, nephews, barracks, shun,
# Nearest to over: speleological, perpetuated, tiled, bulge, mohammed, cry, stanshall, beneficiary,
# Nearest to or: adagio, hur, deutschland, repeaters, georgi, fr, mauritania, unintended,
# Nearest to many: monadic, numismatic, blockbusters, dk, xxviii, ixion, pressuring, burkina,
# Nearest to there: supported, decrypted, prefectural, imagine, spotty, attempted, soleil, slovenes,
# Nearest to at: kemal, broke, separatist, uma, tisza, punts, rd, troopers,
# Nearest to to: orbital, nederlandse, leaked, rodolfo, formic, muppet, elmira, bee,
# Nearest to be: gory, elizabeth, submitted, thematically, horta, crete, slashing, anesthetic,
# Nearest to not: lup, pueblo, bernd, consecutive, kush, reissues, desegregation, juices,
# Nearest to first: evenly, ides, hayden, roskilde, environmentalist, kambojas, cq, seaway,
# Nearest to also: ene, coatings, insufficient, ghanaian, tempted, cure, tms, lycos,
# Nearest to one: duvall, imbued, outwards, drastic, marcus, magnetization, lyra, kanons,
# Average loss at step 2000: 4.035663
# Average loss at step 4000: 3.505210
# Average loss at step 6000: 3.341756
# Average loss at step 8000: 3.190483
# Average loss at step 10000: 3.147105
# Nearest to called: broken, maule, riverview, nominates, ore, sauerkraut, considered, keto,
# Nearest to these: some, cauldron, presses, cafes, brummell, francorum, assets, hypopituitarism,
# Nearest to six: eight, nine, seven, five, four, three, two, zero,
# Nearest to of: suing, amongst, shapes, ostrogoths, across, hlich, colors, for,
# Nearest to see: contagion, shun, ind, kowtow, barracks, boyfriend, pre, westcott,
# Nearest to over: cry, speleological, motorcyclists, beneficiary, tiled, saiyan, core, extinguish,
# Nearest to or: and, tewahedo, ironically, deutschland, soundboard, than, consumer, georgi,
# Nearest to many: some, various, several, numismatic, cataclysm, coliseum, all, blockbusters,
# Nearest to there: it, sometimes, wander, they, stalingrad, decrypted, imperialism, millionaires,
# Nearest to at: in, grooved, on, during, tisza, kemal, psychologists, terminates,
# Nearest to to: will, would, could, jacobites, orbital, steven, truro, mace,
# Nearest to be: was, elizabeth, thematically, is, submitted, formulation, have, jamaicans,
# Nearest to not: also, pots, kush, now, juices, rigorous, lup, bearing,
# Nearest to first: lows, until, gil, kambojas, bullseye, outbursts, gibbon, service,
# Nearest to also: never, not, who, generally, awarding, often, which, bogies,
# Nearest to one: two, eight, nine, six, zero, three, five, exercise,
# Average loss at step 12000: 3.172093
# Average loss at step 14000: 3.126553
# Average loss at step 16000: 3.148477
# Average loss at step 18000: 3.102005
# Average loss at step 20000: 2.991914
# Nearest to called: maule, riverview, considered, broken, keto, bhumi, partly, nominates,
# Nearest to these: some, they, many, those, presses, cauldron, various, assets,
# Nearest to six: seven, eight, five, four, nine, three, zero, two,
# Nearest to of: amongst, suing, ostrogoths, colors, epithet, imine, surrounding, macaulay,
# Nearest to see: boyfriend, barracks, shun, contagion, ample, seventies, westcott, cernunnos,
# Nearest to over: cry, speleological, only, erupts, familias, him, tiled, core,
# Nearest to or: and, phishing, tewahedo, soundboard, than, joked, acute, consumer,
# Nearest to many: some, several, various, these, such, numismatic, those, all,
# Nearest to there: it, they, sometimes, typically, he, wander, theophrastus, blacki,
# Nearest to at: during, in, tisza, grooved, mentha, terminates, albino, bachchan,
# Nearest to to: will, could, jacobites, would, orbital, truro, must, not,
# Nearest to be: is, been, jamaicans, was, elizabeth, have, were, thematically,
# Nearest to not: never, pots, actually, also, patterson, to, generally, usually,
# Nearest to first: second, lows, outbursts, next, last, gil, kambojas, bullseye,
# Nearest to also: generally, never, often, which, yersinia, now, still, who,
# Nearest to one: two, eight, six, five, seven, nine, four, order,
# Average loss at step 22000: 3.049811
# Average loss at step 24000: 3.021237
# Average loss at step 26000: 2.990451
# Average loss at step 28000: 3.014242
# Average loss at step 30000: 2.989533
# Nearest to called: maule, riverview, considered, partly, sauerkraut, keto, vacancies, bhumi,
# Nearest to these: some, many, those, such, they, several, various, assets,
# Nearest to six: four, eight, five, seven, nine, three, two, zero,
# Nearest to of: suing, hlich, ostrogoths, amongst, collage, across, including, in,
# Nearest to see: boyfriend, palais, barracks, shun, contagion, but, cernunnos, westcott,
# Nearest to over: saharan, cry, erupts, familias, clockmaker, core, tiled, speleological,
# Nearest to or: and, than, tewahedo, without, but, spiny, bioethics, scarborough,
# Nearest to many: some, several, various, these, other, caring, those, such,
# Nearest to there: it, they, he, she, sometimes, wander, typically, now,
# Nearest to at: during, tisza, in, grooved, mentha, polled, elam, on,
# Nearest to to: could, must, will, would, jacobites, truro, can, vitality,
# Nearest to be: been, was, jamaicans, thematically, elizabeth, being, is, abreast,
# Nearest to not: actually, never, usually, typically, otherwise, still, now, reissues,
# Nearest to first: next, last, second, outbursts, lows, previous, same, service,
# Nearest to also: often, now, never, generally, still, always, yersinia, which,
# Nearest to one: two, six, five, seven, nine, four, three, eight,
# Average loss at step 32000: 2.841012
# Average loss at step 34000: 2.944025
# Average loss at step 36000: 2.937772
# Average loss at step 38000: 2.938752
# Average loss at step 40000: 2.917501
# Nearest to called: considered, maule, riverview, partly, keto, vacancies, bhumi, bites,
# Nearest to these: such, those, some, many, several, which, various, they,
# Nearest to six: five, eight, seven, four, nine, three, two, zero,
# Nearest to of: ostrogoths, empty, despite, amongst, imine, shreveport, hlich, macaulay,
# Nearest to see: palais, barracks, boyfriend, cernunnos, westcott, shun, decent, fledgling,
# Nearest to over: saharan, into, tiled, declarative, erupts, cry, aquarii, within,
# Nearest to or: and, seizures, tewahedo, than, attaining, spiny, scarborough, naghten,
# Nearest to many: some, several, various, these, those, other, caring, most,
# Nearest to there: they, it, he, she, sometimes, chittagong, typically, still,
# Nearest to at: during, in, mentha, tisza, grooved, polled, bornu, ttt,
# Nearest to to: could, must, will, shall, filesystems, cannot, jacobites, would,
# Nearest to be: been, is, was, being, were, jamaicans, have, thematically,
# Nearest to not: actually, never, usually, otherwise, typically, still, simply, wielding,
# Nearest to first: next, second, last, previous, outbursts, lows, valois, evenly,
# Nearest to also: often, now, never, generally, still, always, usually, which,
# Nearest to one: two, seven, five, six, eight, nine, four, three,
# Average loss at step 42000: 2.937765
# Average loss at step 44000: 2.943822
# Average loss at step 46000: 2.904228
# Average loss at step 48000: 2.866694
# Average loss at step 50000: 2.843484
# Nearest to called: considered, riverview, maule, keto, partly, referred, used, broken,
# Nearest to these: those, such, some, several, various, many, they, which,
# Nearest to six: seven, eight, four, five, nine, three, two, zero,
# Nearest to of: ostrogoths, collage, interstates, hlich, including, epithet, in, amongst,
# Nearest to see: palais, shun, westcott, cernunnos, barracks, chemically, includes, glutamate,
# Nearest to over: saharan, into, within, declarative, tiled, speleological, aquarii, absorbs,
# Nearest to or: and, than, xy, phishing, tewahedo, attaining, hens, herbivore,
# Nearest to many: some, several, various, these, all, few, most, those,
# Nearest to there: they, it, he, chittagong, she, we, typically, sometimes,
# Nearest to at: in, during, tisza, polled, grooved, mentha, bornu, terminates,
# Nearest to to: must, will, would, could, shall, cannot, sld, gens,
# Nearest to be: been, is, being, are, become, jamaicans, were, easily,
# Nearest to not: actually, never, otherwise, almost, simply, usually, still, wielding,
# Nearest to first: next, last, second, outbursts, previous, valois, future, lows,
# Nearest to also: often, now, actually, generally, never, still, always, sometimes,
# Nearest to one: four, seven, six, eight, two, nine, five, three,
# Average loss at step 52000: 2.882448
# Average loss at step 54000: 2.862113
# Average loss at step 56000: 2.859433
# Average loss at step 58000: 2.759823
# Average loss at step 60000: 2.827634
# Nearest to called: considered, used, referred, named, maule, intended, riverview, keto,
# Nearest to these: those, several, such, various, some, many, which, different,
# Nearest to six: seven, eight, four, five, nine, three, two, zero,
# Nearest to of: amongst, ostrogoths, including, interstates, despite, imine, rewind, suing,
# Nearest to see: includes, allow, palais, boyfriend, cernunnos, resolve, barracks, prone,
# Nearest to over: saharan, into, within, declarative, bulge, aquarii, grimoires, absorbs,
# Nearest to or: and, than, phishing, riches, incompetence, domo, herbivore, reinforce,
# Nearest to many: several, some, various, few, these, those, most, all,
# Nearest to there: they, it, he, she, chittagong, undocumented, we, hotspots,
# Nearest to at: during, in, tisza, grooved, polled, frantic, mentha, hasan,
# Nearest to to: must, would, could, will, shall, cannot, towards, alighieri,
# Nearest to be: been, is, become, being, was, were, jamaicans, easily,
# Nearest to not: actually, never, otherwise, usually, almost, still, nothing, always,
# Nearest to first: last, next, second, future, outbursts, previous, evenly, third,
# Nearest to also: often, actually, generally, still, now, never, always, usually,
# Nearest to one: two, six, four, five, nine, seven, eight, three,
# Average loss at step 62000: 2.828687
# Average loss at step 64000: 2.775142
# Average loss at step 66000: 2.770337
# Average loss at step 68000: 2.716389
# Average loss at step 70000: 2.774703
# Nearest to called: considered, named, maule, referred, riverview, used, intended, bhumi,
# Nearest to these: those, several, some, such, various, many, they, which,
# Nearest to six: eight, five, seven, four, nine, three, two, zero,
# Nearest to of: ostrogoths, empty, including, in, imine, epithet, amongst, interstates,
# Nearest to see: cernunnos, includes, barracks, hopped, palais, westcott, decent, subway,
# Nearest to over: saharan, into, within, absorbs, declarative, grimoires, bulge, reduce,
# Nearest to or: and, than, attaining, mosfet, tewahedo, bioethics, scarborough, endosymbiosis,
# Nearest to many: several, some, various, few, most, these, numerous, all,
# Nearest to there: they, it, he, she, we, chittagong, sometimes, typically,
# Nearest to at: during, in, tisza, near, mentha, grooved, frantic, cyrix,
# Nearest to to: will, would, must, could, shall, cannot, jacobites, should,
# Nearest to be: been, being, become, is, was, easily, jamaicans, were,
# Nearest to not: actually, never, otherwise, usually, now, almost, occasionally, always,
# Nearest to first: next, last, second, outbursts, future, third, valois, fourth,
# Nearest to also: actually, often, now, never, still, generally, traditionally, always,
# Nearest to one: two, seven, five, nine, six, three, eight, four,
# Average loss at step 72000: 2.802958
# Average loss at step 74000: 2.658882
# Average loss at step 76000: 2.805445
# Average loss at step 78000: 2.820300
# Average loss at step 80000: 2.783945
# Nearest to called: named, considered, referred, used, riverview, maule, see, rebuilt,
# Nearest to these: those, some, several, such, many, various, which, both,
# Nearest to six: eight, five, seven, four, nine, three, zero, two,
# Nearest to of: epithet, collage, surrounding, forges, suing, interstates, imine, including,
# Nearest to see: include, called, prone, note, linz, hopped, cernunnos, but,
# Nearest to over: saharan, within, absorbs, grimoires, into, epicurus, across, declarative,
# Nearest to or: and, than, though, domo, bioethics, attaining, mosfet, endosymbiosis,
# Nearest to many: several, some, various, most, few, numerous, all, these,
# Nearest to there: they, it, he, she, we, chittagong, sometimes, undocumented,
# Nearest to at: in, during, near, tisza, mentha, bachchan, grooved, polled,
# Nearest to to: would, gens, jacobites, will, towards, alighieri, should, across,
# Nearest to be: been, become, being, is, was, easily, thematically, jamaicans,
# Nearest to not: actually, never, otherwise, almost, occasionally, always, usually, still,
# Nearest to first: next, last, second, third, fourth, future, best, almagest,
# Nearest to also: actually, often, never, now, traditionally, generally, still, always,
# Nearest to one: two, seven, nine, six, five, four, eight, three,
# Average loss at step 82000: 2.672562
# Average loss at step 84000: 2.771665
# Average loss at step 86000: 2.743703
# Average loss at step 88000: 2.758835
# Average loss at step 90000: 2.740352
# Nearest to called: named, referred, used, considered, known, maule, pueblo, mistakenly,
# Nearest to these: those, some, such, several, many, various, different, both,
# Nearest to six: seven, eight, four, five, nine, three, two, zero,
# Nearest to of: imine, collage, ostrogoths, including, suing, epithet, interstates, amongst,
# Nearest to see: include, but, note, list, cernunnos, linz, tls, called,
# Nearest to over: saharan, into, within, across, grimoires, absorbs, declarative, talkie,
# Nearest to or: and, than, attaining, mosfet, though, bioethics, domo, but,
# Nearest to many: several, some, various, few, all, most, these, numerous,
# Nearest to there: they, it, he, she, we, undocumented, chittagong, sometimes,
# Nearest to at: during, in, near, hasan, cyrix, bachchan, tisza, albino,
# Nearest to to: would, could, should, must, cannot, necessarily, towards, alighieri,
# Nearest to be: been, become, being, easily, was, remain, is, jamaicans,
# Nearest to not: actually, never, otherwise, always, occasionally, nothing, almost, usually,
# Nearest to first: next, last, second, third, fourth, almagest, future, best,
# Nearest to also: actually, often, never, now, traditionally, generally, still, always,
# Nearest to one: six, two, seven, eight, four, nine, three, five,
# Average loss at step 92000: 2.689513
# Average loss at step 94000: 2.727286
# Average loss at step 96000: 2.709423
# Average loss at step 98000: 2.375363
# Average loss at step 100000: 2.419083
# Nearest to called: named, referred, used, considered, known, webcam, broken, pueblo,
# Nearest to these: those, such, several, some, many, various, both, certain,
# Nearest to six: eight, five, seven, four, nine, three, two, zero,
# Nearest to of: rewind, interstates, amongst, ostrogoths, despite, epithet, imine, machined,
# Nearest to see: include, note, includes, list, external, called, define, bartle,
# Nearest to over: saharan, within, nearly, absorbs, morbidity, declarative, grimoires, into,
# Nearest to or: and, though, domo, than, bioethics, mosfet, tewahedo, attaining,
# Nearest to many: several, some, various, numerous, few, all, these, those,
# Nearest to there: they, it, he, she, we, sometimes, undocumented, chittagong,
# Nearest to at: in, during, near, tisza, insensitivity, grooved, frantic, bachchan,
# Nearest to to: would, towards, cannot, shall, should, will, must, could,
# Nearest to be: been, being, become, is, was, were, remain, easily,
# Nearest to not: never, actually, always, occasionally, nothing, otherwise, partially, usually,
# Nearest to first: next, last, second, third, future, fourth, best, almagest,
# Nearest to also: actually, often, never, now, still, traditionally, generally, always,
# Nearest to one: two, six, seven, nine, three, five, eight, four,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
